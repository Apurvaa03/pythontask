# %% [markdown]
# # Basic Dictionay Operations

# %% [markdown]
# 1. Create a dictionary with 3 key-value pairs (name, age, city).

# %%
my_dic={"name":"Apurva","age":24,"city":"Kolhapur"}

print(my_dic)
# Out:
# {'name': 'Apurva', 'age': 24, 'city': 'Kolhapur'}

# %% [markdown]
# 2. Create a dictionary and print the value of a specific key.

# %%
print(my_dic)

my_dic["name"]
# Out:
# {'name': 'Apurva', 'age': 24, 'city': 'Kolhapur'}
# 'Apurva'

# %% [markdown]
# 3. Make a dictionary and add a new key-value pair to it.

# %%
dic={"car":"Audi"}

print(dic)

dic.update({"Model":"Q3"})

print(dic)
# Out:
# {'car': 'Audi'}
# {'car': 'Audi', 'Model': 'Q3'}

# %% [markdown]
# 4. Create a dictionary and change the value of an existing key.

# %%
my_dic={"name":"Apurva","age":24,"city":"Kolhapur"}

print(my_dic)

my_dic.update({"city":"Pune"})
print(my_dic)
# Out:
# {'name': 'Apurva', 'age': 24, 'city': 'Kolhapur'}
# {'name': 'Apurva', 'age': 24, 'city': 'Pune'}

# %% [markdown]
# 5. Create a dictionary and remove one key using pop().

# %%
dic1={"name":"Apurva","age":24,"city":"pune"}

print(dic1)

dic1.pop("age")

print(dic1)
# Out:
# {'name': 'Apurva', 'age': 24, 'city': 'pune'}
# {'name': 'Apurva', 'city': 'pune'}

# %% [markdown]
# 6. Create a dictionary and remove the last inserted item using popitem().

# %%
dic1={"name":"Apurva","age":24,"city":"pune"}

print(dic1)

dic1.popitem()

print(dic1)
# Out:
# {'name': 'Apurva', 'age': 24, 'city': 'pune'}
# {'name': 'Apurva', 'age': 24}

# %% [markdown]
# 7. Create a dictionary and print all the keys.

# %%
mydic={"Name":"Apurva","Marks":90,"Sub":"Data Science"}

print(mydic)

mydic.keys()
# Out:
# {'Name': 'Apurva', 'Marks': 90, 'Sub': 'Data Science'}
# dict_keys(['Name', 'Marks', 'Sub'])

# %% [markdown]
# 8. Create a dictionary and print all the values.

# %%
print(mydic)

mydic.values()
# Out:
# {'Name': 'Apurva', 'Marks': 90, 'Sub': 'Data Science'}
# dict_values(['Apurva', 90, 'Data Science'])

# %% [markdown]
# 9. Create a dictionary and print all the key-value items.

# %%
print(mydic)

mydic.items()
# Out:
# {'Name': 'Apurva', 'Marks': 90, 'Sub': 'Data Science'}
# dict_items([('Name', 'Apurva'), ('Marks', 90), ('Sub', 'Data Science')])

# %% [markdown]
# 10. Make a dictionary and check the number of items using len().

# %%
print(mydic)

mydic.__len__()
# Out:
# {'Name': 'Apurva', 'Marks': 90, 'Sub': 'Data Science'}
# 3

# %% [markdown]
# 11. Create a dictionary and check if a certain key exists (using "key" in dict).

# %%
print(mydic)

print(mydic.get("Marks"))
# Out:
# {'Name': 'Apurva', 'Marks': 90, 'Sub': 'Data Science'}
# 90

# %% [markdown]
# 12. Create an empty dictionary and add two key-value pairs one by one.

# %%
dict1={}

dict1["name"]="Apurva"
dict1["Age"]=24

print(dict1)
# Out:
# {'name': 'Apurva', 'Age': 24}

# %% [markdown]
# 13. Create a dictionary and update one key’s value using update().

# %%
print(dict1)

dict1.update({"City":"Pune"})

print(dict1)
# Out:
# {'name': 'Apurva', 'Age': 24}
# {'name': 'Apurva', 'Age': 24, 'City': 'Pune'}

# %% [markdown]
# 14. Create two dictionaries and combine them using update().

# %%
dic2={"Name":"John"}
dic3={"Mark":"90"}

dic2.update(dic3)

print(dic2)
# Out:
# {'Name': 'John', 'Mark': '90'}

# %% [markdown]
# 15. Make a dictionary and get the value of a key using get().

# %%
print(dic2)

dic2.get("Name")
# Out:
# {'Name': 'John', 'Mark': '90'}
# 'John'

# %% [markdown]
# 16. Create a dictionary and print its type using type().

# %%
print(type(dic2))
# Out:
# <class 'dict'>

# %% [markdown]
# 17. Create a dictionary and replace one value with a new one.

# %%
my_dict1 = {"name": "John", "age": 25, "city": "Delhi"}

print(my_dict1)

my_dict1["age"] = 30
print(my_dict1)
# Out:
# {'name': 'John', 'age': 25, 'city': 'Delhi'}
# {'name': 'John', 'age': 30, 'city': 'Delhi'}

# %% [markdown]
# 18. Create a dictionary and clear all items using clear().

# %%
my_dict1 = {"name": "John", "age": 25, "city": "Delhi"}

my_dict1.clear()

print(my_dict1)
# Out:
# {}

# %% [markdown]
# 19. Create a dictionary with numbers as keys and names as values. Print the dictionary.

# %%
num={1:"One",2:"Two",3:"three"}

print(num)
# Out:
# {1: 'One', 2: 'Two', 3: 'three'}

# %% [markdown]
# 20. Create a dictionary and copy it into a new dictionary using copy().

# %%
num={1:"One",2:"Two",3:"three"}

print(num)
numbers=num.copy()

print(numbers)
# Out:
# {1: 'One', 2: 'Two', 3: 'three'}
# {1: 'One', 2: 'Two', 3: 'three'}
